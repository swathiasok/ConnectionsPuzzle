# %%
# !pip install -U "huggingface_hub[cli]"
# Out:
# Requirement already satisfied: huggingface_hub[cli] in /usr/local/lib/python3.11/dist-packages (0.29.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (4.12.2)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (0.3.4)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (3.0.50)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[cli]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[cli]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[cli]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[cli]) (2025.1.31)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface_hub[cli]) (0.2.13)

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Token is valid (permission: write).
# The token `DL_PROJECT` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `DL_PROJECT`

# %%
import pandas as pd
import requests
import random
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from collections import Counter
import numpy as np

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_id = "meta-llama/Llama-3.2-1B-Instruct"
access_token = "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"  # Replace with your actual token

tokenizer = AutoTokenizer.from_pretrained(model_id, use_auth_token=access_token)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,
    device_map="auto",
    use_auth_token=access_token  # Required for gated models
)

# %%
# PROMPTING FUNCTION
def llm_output(words):
  prompt = "You are playing the NY Times Connections game. I will give you 16 words, and your task is to group them into 4 sets of exactly 4 words each, based on a common theme. \
          Find groups of four items that share something in common. \
          Category Examples:\
          FISH: Bass, Flounder, Salmon, Trout\
          FIRE ___: Ant, Drill, Island, Opal\
          Categories will always be more specific than ‘5-LETTER-WORDS’, ‘NAMES’, or ‘VERBS.’\
          Example: \
          **WORDS**: [BUCKS, HAIL, JAZZ, SHIFT, LEVEL, MOM, SNOW, RACECAR, SLEET, TAB, KAYAK, RETURN, OPTION, NETS, RAIN, HEAT]  \
          **SOLUTION**: [['HAIL', 'RAIN', 'SLEET', 'SNOW'], ['BUCKS', 'HEAT', 'JAZZ', 'NETS'], ['OPTION', 'RETURN', 'SHIFT', 'TAB'], ['KAYAK', 'LEVEL', 'MOM', 'RACECAR']]  \
          **EXPLANATION**: \
          WET WEATHER: 'HAIL', 'RAIN', 'SLEET', 'SNOW'\
          NBA TEAMS: 'BUCKS', 'HEAT', 'JAZZ', 'NETS'\
          KEYBOARD KEYS: 'OPTION', 'RETURN', 'SHIFT', 'TAB'\
          PALINDROMES:  'KAYAK', 'LEVEL', 'MOM', 'RACECAR'\
          \
          Categories share commonalities: \
          • There are 4 categories of 4 words each\
          • Every word will be in only 1 category \
          • One word will never be in two categories\
          • There may be a red herrings (words that seems to belong together but actually are in separate categories)\
          • Category may contain compound words with a common prefix or suffix word\
          • A few other common categories include word and letter patterns, pop culture clues (such as music and movie titles) and fill-in-the-blank phrases You will be given a new example (Example 4) with today’s list of words. Give your final answer following the structure below\
          [['word1', 'word2', 'word3', 'word4'],['word5', 'word6', 'word7', 'word8'],['word9', 'word10', 'word11', 'word12'],['word13', 'word14', 'word15', 'word16']]\
          Do NOT include **EXPLANATIONS** or anything except the **SOLUTION** in the above format. Only give one **SOLUTION**\
          Remember that the same word cannot be repeated across multiple categories, and you need to output 4 categories with 4 distinct words each. Also do not make up words not in the list. This is the most important rule. Please obey\
          Now, group the following words correctly:'\
          **WORDS**:" + str(words) + "\**SOLUTION**: "

  inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

  output_ids = model.generate(**inputs, max_length=1000, temperature=0.7, do_sample=True)

  response = tokenizer.decode(output_ids[0], skip_special_tokens=True)

  print("\nResponse:", response)
  return response

# %%
#GET DATA FROM DATASET
url = 'https://raw.githubusercontent.com/Eyefyre/NYT-Connections-Answers/main/connections.json'

response = requests.get(url)

if response.status_code == 200:
    try:
        json_data = response.json()
        df = pd.DataFrame(json_data)

        # print(df)
    except requests.exceptions.JSONDecodeError as e:
        print("JSON decoding failed:", e)
else:
    print(f"Failed to retrieve data: {response.status_code}")

df = df[:650]

# %%
# EVALUATION FUNCTION
def evaluation_scores(actual_clusters, predicted_clusters):
  if len(actual_clusters) == 0 or len(predicted_clusters) == 0:
    return 0
  score_matrix = np.zeros((len(actual_clusters), len(predicted_clusters)))
  jacc_similarity_score = 0

  # Evauating jaccard matching between each pair of sets
  for actual_idx in range(4):
    for predicted_idx in range(4):
      actual_group = actual_clusters[actual_idx]
      predicted_group = predicted_clusters[predicted_idx]
      score_matrix[actual_idx, predicted_idx] = len(set(actual_group) & set(predicted_group)) / len(set(actual_group) | set(predicted_group))

  # Success Rate
  succ_rate = np.sum(np.array(score_matrix) == 1.0)

  total_words = sum(len(cluster) for cluster in predicted_clusters)  # Should be 16 in this case
  max_overlaps = 0
  for pred_cluster in predicted_clusters:
      overlap_counts = Counter()
      for true_cluster in actual_clusters:
          overlap_counts[tuple(true_cluster)] = len(set(pred_cluster) & set(true_cluster))

      max_overlaps += max(overlap_counts.values())  # Take the largest overlap for each predicted cluster
  # print("SUCCESS RATE: ", succ_rate)
  return succ_rate , max_overlaps / total_words

def evaluation(actual_clusters_set, predicted_clusters_set):
  succ_rate = 0
  purity = 0
  num_samples = 0
  for actual_clusters, predicted_clusters in zip(actual_clusters_set, predicted_clusters_set):
    num_samples += 1
    print("ACTUAL CLUSTER:",actual_clusters, " \nPREDICTED CLUSTER: ", predicted_clusters, "\n")
    val1, val2 = evaluation_scores(actual_clusters, predicted_clusters)
    succ_rate += val1
    purity += val2
  print(num_samples)
  return succ_rate/num_samples, purity/num_samples

# %%
# FORMING TRAIN AND TEST SPLIT DATA
# Removal of emoji data
data_mod = []
data_labels_mod = []
flag = 0
for day_sample in df['answers']:
  for cluster in day_sample:
    if sum([True if x.isascii() else False for x in cluster['members']]) != 4:
      flag = 1
      break
  if flag == 1:
    flag = 0
    continue
  for cluster in day_sample:
    data_mod.append(cluster['members'])
    data_labels_mod.append(cluster['group'])

data_mod = np.array(data_mod)
data_labels_mod = np.array(data_labels_mod)
data = data_mod.reshape(int(data_mod.shape[0]/4), 4*4)
data_labels = data_labels_mod.reshape(int(data_labels_mod.shape[0]/4), 4)

train_data, temp_data, train_labels, temp_labels = train_test_split(data, data_labels, test_size=0.2, random_state=101)
# Then split (valid + test) into valid and test
valid_data, test_data, valid_labels, test_labels = train_test_split(temp_data, temp_labels, test_size=0.5, random_state=101)

train_data = train_data.reshape(-1,4)
train_labels = train_labels.reshape(-1,1)

valid_data = valid_data.reshape(-1,4)
valid_labels = valid_labels.reshape(-1,1)

test_data = test_data.reshape(-1,4)
test_labels = test_labels.reshape(-1,1)

train_x = np.array(train_data[:len(train_data) - len(train_data)%4])
train_label = np.array(train_labels[:len(train_data) - len(train_data)%4])
train_x_m1 = train_x.reshape(int(train_x.shape[0]/4),4*4).copy()
train_x_actual_m1 = train_x.reshape(int(train_x.shape[0]/4),4,4).copy()
for i in range(train_x_m1.shape[0]):
  random.shuffle(train_x_m1[i])
print(train_x_m1[0])
print(train_x_m1.shape)

valid_x = np.array(valid_data[:len(valid_data) - len(valid_data)%4])
valid_label = np.array(valid_labels[:len(valid_data) - len(valid_data)%4])
valid_x_m1 = valid_x.reshape(int(valid_x.shape[0]/4),4*4).copy()
valid_x_actual_m1 = valid_x.reshape(int(valid_x.shape[0]/4),4,4).copy()
for i in range(valid_x_m1.shape[0]):
  random.shuffle(valid_x_m1[i])
print(valid_x_m1[0])
print(valid_x_m1.shape)

test_x = np.array(test_data[:len(test_data) - len(test_data)%4])
test_label = np.array(test_labels[:len(test_data) - len(test_data)%4])
test_x_m1 = test_x.reshape(int(test_x.shape[0]/4),4*4).copy()
test_x_actual_m1 = test_x.reshape(int(test_x.shape[0]/4),4,4).copy()
for i in range(test_x_m1.shape[0]):
  random.shuffle(test_x_m1[i])
print(test_x_m1[0])
print(test_x_actual_m1[0])
print(test_x_m1.shape)

tot_x = np.concatenate((train_x, valid_x, test_x), axis=0)
tot_label = np.concatenate((train_label, valid_label, test_label), axis=0)
tot_x_m1 = tot_x.reshape(int(tot_x.shape[0]/4),4*4).copy()
tot_x_actual_m1 = tot_x.reshape(int(tot_x.shape[0]/4),4,4).copy()
for i in range(tot_x_m1.shape[0]):
  random.shuffle(tot_x_m1[i])
print(tot_x_m1[0])
print(tot_x_m1.shape)
# Out:
# ['GUILT' 'EGO' 'MUST' 'GUIDE' 'EXPRESSION' 'POWER' 'TOKEN' 'MOLD' 'SYMBOL'
#  'MIGHT' 'MODEL' 'HEAD' 'GESTURE' 'BLUEPRINT' 'WILL' 'CAN']
# (516, 16)
# ['MOON' 'MONTY' 'VIPER' 'TEDDY' 'MAMBA' 'ABSTRACT' 'RUNDOWN' 'DIGEST'
#  'CIRCLE' 'BRIEF' 'PYTHON' 'HOUSE' 'GARTER' 'THONG' 'SLIP' 'BOA']
# (65, 16)
# ['PROGRESS' 'ABSURDITY' 'GARBAGE' 'FEET' 'SIX' 'NONSENSE' 'PUSH' 'FOLLY'
#  'FAKE' 'ADVANCE' 'CHEESE' 'CUT' 'MADNESS' 'MARCH' 'FREEZE' 'SKUNK']
# [['ABSURDITY' 'FOLLY' 'MADNESS' 'NONSENSE']
#  ['ADVANCE' 'MARCH' 'PROGRESS' 'PUSH']
#  ['CHEESE' 'FEET' 'GARBAGE' 'SKUNK']
#  ['CUT' 'FAKE' 'FREEZE' 'SIX']]
# (65, 16)
# ['MIGHT' 'WILL' 'SYMBOL' 'MODEL' 'CAN' 'MOLD' 'TOKEN' 'POWER' 'BLUEPRINT'
#  'EXPRESSION' 'GUIDE' 'GUILT' 'HEAD' 'GESTURE' 'EGO' 'MUST']
# (646, 16)

# %%
# TO STORE LLM RESPONSE
LLM_RESPONSE = []
llm_responses_text_list = []

# %%
# TO EXTRACT RESPONSES SAVED IN TEXT FILE
import re

def extract_responses(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        text = file.read()

    # Use regex to find all responses
    responses = re.findall(r"Response:\s*(.*?)(?=\nResponse:|\Z)", text, re.DOTALL)
    return [response.strip() for response in responses]

# Example usage
file_path = "RESPONSES (1).txt"  # Replace with your actual file path
responses = extract_responses(file_path)
# print(responses)
# for i, response in enumerate(responses, 1):
#     print(f"Response {i}:\n{response}\n{'-'*80}")
responses[1]
# Out:
# "You are playing the NY Times Connections game. I will give you 16 words, and your task is to group them into 4 sets of exactly 4 words each, based on a common theme.           Find groups of four items that share something in common.           Category Examples:          FISH: Bass, Flounder, Salmon, Trout          FIRE ___: Ant, Drill, Island, Opal          Categories will always be more specific than ‘5-LETTER-WORDS’, ‘NAMES’, or ‘VERBS.’          Example:           **WORDS**: [BUCKS, HAIL, JAZZ, SHIFT, LEVEL, MOM, SNOW, RACECAR, SLEET, TAB, KAYAK, RETURN, OPTION, NETS, RAIN, HEAT]            **SOLUTION**: [['HAIL', 'RAIN', 'SLEET', 'SNOW'], ['BUCKS', 'HEAT', 'JAZZ', 'NETS'], ['OPTION', 'RETURN', 'SHIFT', 'TAB'], ['KAYAK', 'LEVEL', 'MOM', 'RACECAR']]            **EXPLANATION**:           WET WEATHER: 'HAIL', 'RAIN', 'SLEET', 'SNOW'          NBA TEAMS: 'BUCKS', 'HEAT', 'JAZZ', 'NETS'          KEYBOARD KEYS: 'OPTION', 'RETURN', 'SHIFT', 'TAB'          PALINDROMES:  'KAYAK', 'LEVEL', 'MOM', 'RACECAR'                    Categories share commonalities:           • There are 4 categories of 4 words each          • Every word will be in only 1 category           • One word will never be in two categories          • There may be a red herrings (words that seems to belong together but actually are in separate categories)          • Category may contain compound words with a common prefix or suffix word          • A few other common categories include word and letter patterns, pop culture clues (such as music and movie titles) and fill-in-the-blank phrases You will be given a new example (Example 4) with today’s list of words. Give your final answer following the structure below          [['word1', 'word2', 'word3', 'word4'],['word5', 'word6', 'word7', 'word8'],['word9', 'word10', 'word11', 'word12'],['word13', 'word14', 'word15', 'word16']]          Do NOT include **EXPLANATIONS** or anything except the **SOLUTION** in the above format. Only give one **SOLUTION**          Remember that the same word cannot be repeated across multiple categories, and you need to output 4 categories with 4 distinct words each. Also do not make up words not in the list. This is the most important rule. Please obey          Now, group the following words correctly:'          **WORDS**:['GOATEE' 'HORSEFEATHERS' 'POLE' 'PITCHFORK' 'BATON' 'HURDLE' 'TAIL'\n 'SHEEPSHANK' 'BOWLINE' 'HITCH' 'HAMMER' 'CROCK' 'HORNS' 'BEND' 'BUNK'\n 'HOGWASH']\\**SOLUTION**:  [['POLE', 'HORSEFEATHERS', 'GOATEE', 'HURDLE'], ['POLE', 'BATON', 'HORNS', 'HITCH'], ['POLE', 'BOWLINE', 'CROCK', 'HAMMER'], ['POLE', 'HORSEFEATHERS', 'SHEEPSHANK', 'BEND']]          **EXPLANATION**:           HORSE FEATHERS: 'HORSEFEATHERS', 'POLE', 'GOATEE', 'HURDLE'          BATELS: 'BATON', 'BOWLINE', 'CROCK', 'HAMMER'          HANGING: 'HITCH', 'HORNS', 'HOGWASH', 'BEND'          HANGING BASKET: 'POLE', 'BOWLINE', 'SHEEPSHANK', 'BEND'          Categories share commonalities:           • There are 4 categories of 4 words each           • Every word will be in only 1 category           • One word will never be in two categories          • There may be a red herrings (words that seems to belong together but actually are in separate categories)          • Category may contain compound words with a common prefix or suffix word          • A few other common categories include word and letter patterns, pop culture clues (such as music and movie titles) and fill-in-the-blank phrases You will be"

# %%
# TO EXTRACT BEST POSSIBLE SOLUTION FROM THE LLM RESPONSE. THIS IS IN CASE LLM PROVIDES MULTIPLE RESPONSES
import re
import ast

def extract_best_solution(response_text):
    # Regular expression to find **SOLUTION** blocks containing a 4x4 matrix
    solution_pattern = r"\*\*SOLUTION\*\*:\s*(\[\[.*?\]\])"

    # Find all matches
    matches = re.findall(solution_pattern, response_text, re.DOTALL)

    best_solution = None
    n = len(matches)
    for i in range(1,n):
        match = matches[i]
        # if i==0:
        #   continue
        try:
            # Convert string to Python list
            solution = ast.literal_eval(match)

            # Ensure it's a 4x4 matrix
            if isinstance(solution, list) and len(solution) == 4 and all(len(group) == 4 for group in solution):
                best_solution = solution
                break  # Stop at the first valid 4x4 matrix

        except (SyntaxError, ValueError):
            continue  # Skip invalid solutions

    return best_solution

# # Example usage
# for resp in responses:
#   # response_text = responses[0]  # Replace with actual LLM response text
#   best_solution = extract_best_solution(resp)
#   # print(type(best_solution[0]))
#   if best_solution:
#       pass
#       print("Best Solution Found:")
#       for group in best_solution:
#           print(group)
#   else:
#       print("No valid solution found.")

# %%
import ast
import re
# CONVERTS THE SOLUTION GIVEN BY LLM FROM STRING TO A 2D ARRAY
# def convert_to_2d_array(input_string):
#     # Add double quotes around each word using regex
#     formatted_string = re.sub(r'(\w+)', r'"\1"', input_string)

#     # Ensure proper list syntax
#     formatted_string = formatted_string.replace("'","")
#     formatted_string = formatted_string.replace('[', '[ ').replace(']', ' ]')

#     try:
#         # Safely evaluate the formatted string as a list of lists
#         output_list = ast.literal_eval(formatted_string)

#         # Convert to a numpy array
#         np_array = np.array(output_list)
#         return np_array

#     except Exception as e:
#         print(f"Error while processing the input string: {e}")
#         return None

# EITHER CALLS LLM OR CHECKS RESPONSE FROM SAVED TEXT FILE AND PROCESSES IT TO RETURN THE BEST SUGGESTED SOLUTION IN 2D MATRIX FORMAT
def llm_model(words, file, count, flag):
  try:
    if flag:
      output = llm_output(words)
    else:
      output = responses[count]
    LLM_RESPONSE.append(output)
    file.write(output)

    solution_output = extract_best_solution(output)
    modified_out = np.array(solution_output)

    if modified_out.shape != (4,4):
        modified_out = np.zeros((4,4), dtype=str)
  except Exception as e:
    print(f"An error occurred: {e}")
    modified_out = np.zeros((4,4), dtype=str)
  return modified_out

# def llm_model(words, file, count, flag):
#   try:
#     if flag:
#       output = llm_output(words)
#     else:
#       output = responses[count]
#     LLM_RESPONSE.append(output)
#     file.write(output)
#     # print("gurfjrhjb",output)
#     # output = "You are playing the NY Times Connections game. I will give you 16 words, and your task is to group them into 4 sets of exactly 4 words each, based on a common theme.           Find groups of four items that share something in common.           Category Examples:          FISH: Bass, Flounder, Salmon, Trout          FIRE ___: Ant, Drill, Island, Opal          Categories will always be more specific than ‘5-LETTER-WORDS’, ‘NAMES’, or ‘VERBS.’          Example:           Words: [BUCKS, HAIL, JAZZ, SHIFT, LEVEL, MOM, SNOW, RACECAR, SLEET, TAB, KAYAK, RETURN, OPTION, NETS, RAIN, HEAT]            Solution: [['HAIL', 'RAIN', 'SLEET', 'SNOW'], ['BUCKS', 'HEAT', 'JAZZ', 'NETS'], ['OPTION', 'RETURN', 'SHIFT', 'TAB'], ['KAYAK', 'LEVEL', 'MOM', 'RACECAR']]            Explanation:           WET WEATHER: 'HAIL', 'RAIN', 'SLEET', 'SNOW'          NBA TEAMS: 'BUCKS', 'HEAT', 'JAZZ', 'NETS'          KEYBOARD KEYS: 'OPTION', 'RETURN', 'SHIFT', 'TAB'          PALINDROMES:  'KAYAK', 'LEVEL', 'MOM', 'RACECAR'                    Categories share commonalities:           • There are 4 categories of 4 words each          • Every word will be in only 1 category           • One word will never be in two categories          • There may be a red herrings (words that seems to belong together but actually are in separate categories)          • Category may contain compound words with a common prefix or suffix word          • A few other common categories include word and letter patterns, pop culture clues (such as music and movie titles) and fill-in-the-blank phrases You will be given a new example (Example 4) with today’s list of words. Give your final answer following the structure below          **SOLUTION**: [['word1', 'word2', 'word3', 'word4'],['word5', 'word6', 'word7', 'word8'],['word9', 'word10', 'word11', 'word12'],['word13', 'word14', 'word15', 'word16']]          Do NOT include explanations for your groupings          Remember that the same word cannot be repeated across multiple categories, and you need to output 4 categories with 4 distinct words each. Also do not make up words not in the list. This is the most important rule. Please obey          Now, group the following words correctly:            **Words:**['MARCH' 'FOLLY' 'NONSENSE' 'CHEESE' 'SIX' 'GARBAGE' 'PROGRESS' 'MADNESS' 'FEET' 'PUSH' 'ADVANCE' 'FREEZE' 'ABSURDITY' 'CUT' 'SKUNK' 'FAKE']\**SOLUTION**:  [['MARCH', 'FOLLY', 'NONSENSE', 'SIX'], ['CHEESE', 'GARBAGE', 'FEET', 'PROGRESS'], ['MADNESS', 'ADVANCE', 'FREEZE', 'SKUNK'], ['ABSURDITY', 'PUSH', 'CUT', 'FAKE']]"
#     # print("kjrfuerjb", type(output))
#     solution_output = output.split("**SOLUTION**:")[-1]
#     solution_output = solution_output.split("]]")[0]
#     solution_output += "]]"
#     print("\nEXTRACTED OUTPUT",solution_output)
#     modified_out = convert_to_2d_array(solution_output)
#     #np.array([x + ['0']*(4-len(x)) for x in ast.literal_eval((output).replace('\n','').replace(' ',''))])
#     # print("kguegwdjn",modified_out)
#     # print("kfheuhiwn", modified_out.shape)
#     if modified_out.shape != (4,4):
#         modified_out = np.zeros((4,4), dtype=str)
#   except Exception as e:
#     # Handle any exception
#     print(f"An error occurred: {e}")
#     modified_out = np.zeros((4,4), dtype=str)
#   return modified_out

# %%
import time
# CALLS LLM ONE BY ONE FOR EACH PUZZLE IN CURRENT SET AND STORES ALL RESPONSES IN AN ARRAY. CLUSTERS_M1 WILL BE A 3D ARRAY
def llm_model_eval(train_x, missed_samples_file_path = 'sample_data/missed.txt'):
  # data processing m1
  clusters_m1 = []
  errored_m1 = []
  file = open('llm_response.txt', 'w')
  cnt = 0
  for x in tqdm(train_x):
    # print("lehiwhn",x)
    out = llm_model(x, file, cnt, False)
    # print(out)
    # time.sleep(2)
    clusters_m1.append(out)
    cnt+=1
  file.close()

  # print missed inputs
  f = open(missed_samples_file_path, 'w')
  for x in errored_m1:
    f.write(str(x) + '\n')
  f.close()
  print(f'Number of errored samples: {len(errored_m1)}')
  return clusters_m1

# %%
def llm_pipeline(x_data, actual_data, numpy_save_file = 'sample_data/train_x_predicted_m1.npy'):
  clusters_m1 = llm_model_eval(x_data)
  succ, purity = evaluation(actual_data, clusters_m1)
  print(f'Success Rate: {succ}')
  print(f'Purity: {purity}')

  np.save(numpy_save_file, clusters_m1)

  missed_cnt = []
  for i, x in enumerate(clusters_m1):
    if np.sum(x == np.zeros((4,4), dtype=str)) == 16:
      missed_cnt.append(i)
  print(f'Count of Missed samples: {len(missed_cnt)}')
  return succ, purity, missed_cnt

# %%
# print('llm: train')
# train_succ, train_jacc, train_missing = llm_pipeline(train_x_m1, train_x_actual_m1,'sample_data/train_x_predicted_m1.npy')
# print('llm: valid')
# valid_succ, valid_jacc, valid_missing  = llm_pipeline(valid_x_m1, valid_x_actual_m1,'sample_data/valid_x_predicted_m1.npy')
print('llm: test')
test_succ, test_purity, test_missing = llm_pipeline(test_x_m1, test_x_actual_m1,'sample_data/test_x_predicted_m1.npy')
# print('llm: All')
# tot_succ, tot_jacc, tot_missing = llm_pipeline(tot_x_m1, tot_x_actual_m1,'sample_data/tot_x_predicted_m1.npy')
# Out:
# llm: test
# 100%|██████████| 65/65 [00:00<00:00, 8046.21it/s]
# Number of errored samples: 0
# ACTUAL CLUSTER: [['ABSURDITY' 'FOLLY' 'MADNESS' 'NONSENSE']
#  ['ADVANCE' 'MARCH' 'PROGRESS' 'PUSH']
#  ['CHEESE' 'FEET' 'GARBAGE' 'SKUNK']
#  ['CUT' 'FAKE' 'FREEZE' 'SIX']]
# PREDICTED CLUSTER:  [['FAKE' 'PROGRESS' 'FEET' 'MADNESS']
#  ['ABSURDITY' 'SIX' 'CUT' 'SKUNK']
#  ['ADVANCE' 'GARBAGE' 'MARCH' 'PUSH']
#  ['CHEESE' 'FOLLY' 'NONSENSE' 'FREEZE']]
#
# ACTUAL CLUSTER: [['BUNK' 'CROCK' 'HOGWASH' 'HORSEFEATHERS']
#  ['BATON' 'HAMMER' 'HURDLE' 'POLE']
#  ['GOATEE' 'HORNS' 'PITCHFORK' 'TAIL']
#  ['BEND' 'BOWLINE' 'HITCH' 'SHEEPSHANK']]
# PREDICTED CLUSTER:  [['POLE' 'HORSEFEATHERS' 'GOATEE' 'HURDLE']
#  ['POLE' 'BATON' 'HORNS' 'HITCH']
#  ['POLE' 'BOWLINE' 'CROCK' 'HAMMER']
#  ['POLE' 'HORSEFEATHERS' 'SHEEPSHANK' 'BEND']]
#
# ACTUAL CLUSTER: [['BRIGHT' 'CLEVER' 'QUICK' 'SHARP']
#  ['ALASKA' 'FRONTIER' 'SOUTHWEST' 'SPIRIT']
#  ['COWBOY' 'DRIFTER' 'OUTLAW' 'SHERIFF']
#  ['LASSO' 'MARS' 'ROGERS' 'SMART']]
# PREDICTED CLUSTER:  [['SOUTHWEST' 'BRIGHT' 'ALASKA' 'MARS']
#  ['SHERIFF' 'DRIFTER' 'QUICK' 'COWBOY']
#  ['SMART' 'FRONTIER' 'ROGERS' 'SPIRIT']
#  ['LASSO' 'OUTLAW' 'SHARP' 'CLEVER']]
#
# ACTUAL CLUSTER: [['ALTAR' 'RELIQUARY' 'SHRINE' 'TEMPLE']
#  ['FELIX' 'GARFIELD' 'SYLVESTER' 'TOM']
#  ['CALVIN' 'CHESTER' 'GROVER' 'HARRY']
#  ['ABBEY' 'HIGH' 'ROCKY' 'SILK']]
# PREDICTED CLUSTER:  [['HARRY' 'SILK' 'TOM' 'GARFIELD']
#  ['ABBEY' 'ALTAR' 'CALVIN' 'ROCKY']
#  ['FELIX' 'HIGH' 'HARRY' 'GROVER']
#  ['CHESTER' 'GARFIELD' 'GROVER' 'SILK']]
#
# ACTUAL CLUSTER: [['HURRY' 'NOW' 'PRONTO' 'STAT']
#  ['CURRENT' 'DRIFT' 'TIDE' 'WAVE']
#  ['CURL' 'FLY' 'PRESS' 'ROW']
#  ['LOCK' 'MARKS' 'PANE' 'RUSTLE']]
# PREDICTED CLUSTER:  [['LOCK' 'DRIFT' 'HURRY' 'PRONTO']
#  ['ROW' 'TIDE' 'CURRENT' 'FLY']
#  ['MARKS' 'PANE' 'PRESS' 'STAT']
#  ['CURL' 'RUSTLE' 'NOW' 'WAVE']]
#
# ACTUAL CLUSTER: [['FRONTIER' 'SPIRIT' 'UNITED' 'VIRGIN']
#  ['BETA' 'CHI' 'DELTA' 'IOTA']
#  ['GNAT' 'GNAW' 'GNOCCHI' 'GNOME']
#  ['GNU' 'KNEW' 'NEW' 'NU']]
# PREDICTED CLUSTER:  [['GNAT' 'GNAW' 'GNOCCHI' 'UNITED']
#  ['DELTA' 'FRONTIER' 'GNOME' 'VIRGIN']
#  ['BETA' 'CHI' 'SPIRIT' 'NEW']
#  ['IOTA' 'KNEW' 'NU' 'VIRGIN']]
#
# ACTUAL CLUSTER: [['BELT' 'BLOW' 'SOCK' 'SLUG']
#  ['SANDWICH' 'SHOEHORN' 'SQUEEZE' 'WEDGE']
#  ['CATERPILLAR' 'DOVE' 'GREYHOUND' 'PUMA']
#  ['INDY' 'METTLE' 'SEOUL' 'WRAP']]
# PREDICTED CLUSTER:  [['INDY' 'BELT' 'METTLE' 'SHOEHORN']
#  ['GREYHOUND' 'SOCK' 'PUMA' 'SEOUL']
#  ['CATERPILLAR' 'SQUEEZE' 'WEDGE' 'DOVE']
#  ['WRAP' 'SLUG' 'SHOEHORN' 'GREYHOUND']]
#
# ACTUAL CLUSTER: [['GAS' 'LIQUID' 'PLASMA' 'SOLID']
#  ['GREAT' 'HERO' 'ICON' 'LEGEND']
#  ['PHAT' 'PHEW' 'PHILLY' 'PHISH']
#  ['ELEVATOR' 'FEVER' 'PERFECT' 'SALES']]
# PREDICTED CLUSTER:  [['GAS' 'FEVER' 'PHISH' 'PHAT']
#  ['ELEVATOR' 'LIQUID' 'PHILLY' 'GREAT']
#  ['PLASMA' 'PHAT' 'PHILLY' 'LEGEND']
#  ['HERO' 'ICON' 'SOLID' 'PHILLY']]
#
# ACTUAL CLUSTER: [['COACH' 'GUIDE' 'SCHOOL' 'TRAIN']
#  ['BANK' 'POOL' 'RESERVE' 'STORE']
#  ['BRAKE' 'PARK' 'SIGNAL' 'TURN']
#  ['BOOK' 'EARTH' 'GLOW' 'INCH']]
# PREDICTED CLUSTER:  [['BOOK' 'INCH' 'TRAIN' 'PARK']
#  ['EARTH' 'GLOW' 'GUIDE' 'SIGNAL']
#  ['RESERVE' 'STORE' 'SCHOOL' 'BANK']
#  ['TURN' 'BRAKE' 'POOL' 'COACH']]
#
# ACTUAL CLUSTER: [['CHASE' 'HUNT' 'QUEST' 'SEARCH']
#  ['ALWAYS' 'KISSES' 'LOVE' 'YOURS']
#  ['CAMP' 'PARTY' 'SIDE' 'WING']
#  ['BOND' 'LEAF' 'MINE' 'RUSH']]
# PREDICTED CLUSTER:  [['KISSES' 'LOVE' 'WING' 'SIDE']
#  ['YOURS' 'BOND' 'QUEST' 'RUSH']
#  ['PARTY' 'ALWAYS' 'CHASE' 'SEARCH']
#  ['MINE' 'CAMP' 'HUNT' 'HUNT']]
#
# ACTUAL CLUSTER: [['AROMA' 'BOUQUET' 'FRAGRANCE' 'SCENT']
#  ['BLUES' 'COUNTRY' 'FUNK' 'SOUL']
#  ['PAPER' 'ROCK' 'SCISSORS' 'SHOOT']
#  ['BOAR' 'BUCK' 'BULL' 'JACK']]
# PREDICTED CLUSTER:  [['FUNK' 'COUNTRY' 'AROMA' 'BOUQUET']
#  ['JACK' 'SHOOT' 'BOAR' 'SOUL']
#  ['PAPER' 'SCENT' 'SCISSORS' 'ROCK']
#  ['BUCK' 'BULL' 'FRAGRANCE' 'BLUES']]
#
# ACTUAL CLUSTER: [['AIRPLANE' 'DO NOT DISTURB' 'RING' 'VIBRATE']
#  ['DODGE' 'ESCAPE' 'LOSE' 'SHAKE']
#  ['TUNGSTEN' 'WATT' 'WEST' 'WIN']
#  ['DRAW' 'HAM' 'HEART' 'SHOE']]
# PREDICTED CLUSTER:  [['HEART' 'WIN' 'WATT' 'DODGE']
#  ['TUNGSTEN' 'SHOE' 'HAM' 'VIBRATE']
#  ['DO NOT' 'AIRPLANE' 'ESCAPE' 'LOSE']
#  ['SHAKE' 'RING' 'WEST' 'DRAW']]
#
# ACTUAL CLUSTER: [['FLUID' 'GRACEFUL' 'NATURAL' 'SMOOTH']
#  ['EFFORT' 'LABOR' 'SWEAT' 'WORK']
#  ['BATTERY' 'CHARGE' 'JUICE' 'POWER']
#  ['BURST' 'DAD' 'MAINSTREAM' 'SODA']]
# PREDICTED CLUSTER:  [['BATTERY' 'CHARGE' 'FLUID' 'SODA']
#  ['NATURAL' 'LABOR' 'POWER' 'SWEAT']
#  ['DAD' 'EFFORT' 'GRACEFUL' 'JUICE']
#  ['MAINSTREAM' 'SMOOTH' 'WORK' 'BURST']]
#
# ACTUAL CLUSTER: [['CENTRAL' 'CRITICAL' 'KEY' 'VITAL']
#  ['GLASS' 'METAL' 'PAPER' 'PLASTIC']
#  ['HENRY' 'JENNIFER' 'KATE' 'ROCK']
#  ['ASSIGNMENT' 'DEFEAT' 'TEMPO' 'TIRED']]
# PREDICTED CLUSTER:  [['DEFEAT' 'ROCK' 'PAPER' 'HENRY']
#  ['CENTRAL' 'GLASS' 'METAL' 'KEY']
#  ['JENNIFER' 'VITAL' 'CRITICAL' 'TEMPO']
#  ['ASSIGNMENT' 'PLASTIC' 'TEMPO' 'KATE']]
#
# ACTUAL CLUSTER: [['BASSOON' 'CLARINET' 'FLUTE' 'OBOE']
#  ['CAP' 'COVER' 'LID' 'TOP']
#  ['AVIATOR' 'CAT EYE' 'WAYFARER' 'WRAPAROUND']
#  ['HARBOR' 'HARP' 'HOODED' 'MONK']]
# PREDICTED CLUSTER:  [['MONK' 'HARP' 'LID' 'OBOE']
#  ['AVIATOR' 'BASSOON' 'CAT EYE' 'HARP']
#  ['COVER' 'HOODED' 'WAYFARER' 'TOP']
#  ['FLUTE' 'HARBOR' 'LID' 'COVER']]
#
# ACTUAL CLUSTER: [['BOOT' 'BOUNCE' 'EJECT' 'TOSS']
#  ['EARTH' 'GROUND' 'LAND' 'SOIL']
#  ['BALTIC' 'BLACK' 'PHILIPPINE' 'RED']
#  ['BIG' 'PHILADELPHIA' 'SPLASH' 'SULLY']]
# PREDICTED CLUSTER:  [['BALTIC' 'LAND' 'PHILIPPINE' 'PHILADELPHIA']
#  ['BIG' 'BLACK' 'EARTH' 'GROUND']
#  ['EJECT' 'EARTH' 'RED' 'SPLASH']
#  ['BOUNCE' 'BOOT' 'SULLY' 'SOIL']]
#
# ACTUAL CLUSTER: [['CARAVAN' 'FLEET' 'PARADE' 'TRAIN']
#  ['OLIVE' 'FOREST' 'LIME' 'MINT']
#  ['DEMOCRATIC' 'EROTIC' 'NOBLE' 'SAD']
#  ['BOOK' 'CACTUS' 'HEDGEHOG' 'SKELETON']]
# PREDICTED CLUSTER:  [['' '' '' '']
#  ['' '' '' '']
#  ['' '' '' '']
#  ['' '' '' '']]
#
# ACTUAL CLUSTER: [['BEARD' 'GOATEE' 'MUSTACHE' 'STUBBLE']
#  ['GEAR' 'HANDLEBAR' 'PEDAL' 'WHEEL']
#  ['DOG' 'FOLLOW' 'TAIL' 'TRACK']
#  ['DOUBT' 'MOVIE' 'SHADOW' 'VOTE']]
# PREDICTED CLUSTER:  [['MUSTACHE' 'HANDLEBAR' 'SHADOW' 'DOUBT']
#  ['GEAR' 'GOATEE' 'PEDAL' 'VOTE']
#  ['DOG' 'WHEEL' 'STUBBLE' 'FOLLOW']
#  ['BEARD' 'TRACK' 'TAIL' 'MOVE']]
#
# ACTUAL CLUSTER: [['CHIME' 'DING' 'PING' 'RING']
#  ['RAT' 'SING' 'SNITCH' 'SQUEAL']
#  ['CAMP' 'DIVISION' 'FACTION' 'WING']
#  ['BING' 'EDGE' 'SURFACE' 'WORD']]
# PREDICTED CLUSTER:  [['RING' 'PING' 'PING' 'WING']
#  ['BING' 'FACTION' 'CHIME' 'CAMP']
#  ['SQUEAL' 'SING' 'SURFACE' 'EDGE']
#  ['SNITCH' 'DIVISION' 'DING' 'WORD']]
#
# ACTUAL CLUSTER: [['MONITOR' 'SURVEY' 'TRACK' 'WATCH']
#  ['BEACH' 'DESERT' 'HOURGLASS' 'PLAYGROUND']
#  ['BAKE' 'BROIL' 'LIGHT' 'TIMER']
#  ['BLUR' 'OASIS' 'PULP' 'SUEDE']]
# PREDICTED CLUSTER:  [['BEACH' 'DESERT' 'MONITOR' 'PULP']
#  ['BROIL' 'LIGHT' 'TIMER' 'SUEDE']
#  ['BLUR' 'BAKE' 'OASIS' 'WATCH']
#  ['HOURGLASS' 'PLAYGROUND' 'SURVEY' 'TRACK']]
#
# ACTUAL CLUSTER: [['CROSS' 'SHORT' 'SURLY' 'TESTY']
#  ['EXPLORATORY' 'PILOT' 'PRELIMINARY' 'TRIAL']
#  ['FIDDLER' 'JERSEY' 'KINKY' 'MERRILY']
#  ['PAN' 'PARKER' 'PIPER' 'RABBIT']]
# PREDICTED CLUSTER:  [['EXPLORATORY' 'Pilot' 'Kinky' 'Piper']
#  ['TESTY' 'Rabbit' 'Short' 'Parker']
#  ['Trial' 'Merrily' 'Surly' 'Cross']
#  ['Cross' 'Preliminary' 'Jersey' 'Fiddler']]
#
# ACTUAL CLUSTER: [['HOE' 'PLOW' 'RAKE' 'SICKLE']
#  ['PLOT' 'PLOY' 'RUSE' 'TRICK']
#  ['AMUSE' 'DELIGHT' 'PLEASE' 'TICKLE']
#  ['BANG' 'PLOP' 'SPLASH' 'THUD']]
# PREDICTED CLUSTER:  [['HOE' 'PLOP' 'RAKE' 'BANG']
#  ['DELIGHT' 'THUD' 'SICKLE' 'PLOT']
#  ['PICK' 'PLEASE' 'SPLASH' 'HOE']
#  ['PICK' 'PLAY' 'AMUSE' 'PLOW']]
#
# ACTUAL CLUSTER: [['CHEESECAKE' 'FLAN' 'MOUSSE' 'TIRAMISU']
#  ['DARN' 'FUDGE' 'HECK' 'SHOOT']
#  ['ELEPHANT' 'HIPPO' 'NARWHAL' 'WARTHOG']
#  ['HANDLEBAR' 'HORSESHOE' 'PENCIL' 'WALRUS']]
# PREDICTED CLUSTER:  [['' '' '' '']
#  ['' '' '' '']
#  ['' '' '' '']
#  ['' '' '' '']]
#
# ACTUAL CLUSTER: [['NEAT' 'NIFTY' 'SUPER' 'SWELL']
#  ['ELABORATE' 'EXPAND' 'EXPLAIN' 'SPECIFY']
#  ['FACILITY' 'FLAIR' 'GIFT' 'KNACK']
#  ['BLOCK' 'COMPLEX' 'COMPOUND' 'DEVELOPMENT']]
# PREDICTED CLUSTER:  [['EXPLAIN' 'ELABORATE' 'FACILITY' 'KNACK']
#  ['NIFTY' 'BLOCK' 'COMPOUND' 'SUPER']
#  ['DEVELOPMENT' 'EXPAND' 'SPECIFY' 'FLAIR']
#  ['COMPLEX' 'SWELL' 'GIFT' 'NEAT']]
#
# ACTUAL CLUSTER: [['BLOWOUT' 'COLOR' 'CUT' 'TRIM']
#  ['BASH' 'BLAST' 'PAN' 'SLAM']
#  ['BAG' 'LAND' 'SCORE' 'SNAG']
#  ['ATTEMPT' 'RECEPTION' 'SACK' 'YARD']]
# PREDICTED CLUSTER:  [['ATTEMPT' 'BAG' 'LAND' 'SLAM']
#  ['BLAST' 'BASH' 'COLOR' 'PAN']
#  ['CUT' 'RECEPTION' 'SACK' 'TRIM']
#  ['SCOR' 'YARD' 'BLOWOUT' 'SNOG']]
#
# ACTUAL CLUSTER: [['CRICKET' 'FENCING' 'POLO' 'SQUASH']
#  ['CAMI' 'HALTER' 'TANK' 'TEE']
#  ['BEET' 'CARROT' 'CORN' 'ONION']
#  ['ANT' 'BEETLE' 'MANTIS' 'TERMITE']]
# PREDICTED CLUSTER:  [['BEETLE' 'CRICKET' 'FENCING' 'MANTIS']
#  ['CARROT' 'CORN' 'HALTER' 'ONION']
#  ['ANT' 'BEET' 'CAMI' 'TEE']
#  ['POLO' 'SQUASH' 'TERMITE' 'TANK']]
#
# ACTUAL CLUSTER: [['FURNISH' 'OUTFIT' 'PROVISION' 'STOCK']
#  ['BEING' 'CHARACTER' 'EGO' 'SELF']
#  ['CHEST' 'CONSOLE' 'VANITY' 'WARDROBE']
#  ['CANT' 'ID' 'SHELL' 'WERE']]
# PREDICTED CLUSTER:  [['CHARACTER' 'WARDROBE' 'VANITY' 'EGO']
#  ['PROVISION' 'CANT' 'FURNISH' 'STOCK']
#  ['BEING' 'CONSOLE' 'CHEST' 'ID']
#  ['SHELL' 'OUTFIT' 'WERE' 'SELF']]
#
# ACTUAL CLUSTER: [['AREA' 'DOMAIN' 'FIELD' 'SPHERE']
#  ['FIDDLE' 'HORN' 'RECORDER' 'TRIANGLE']
#  ['BARRIER' 'CONE' 'FLAG' 'FLARE']
#  ['CHAIN' 'FIGHT' 'PROCESSOR' 'PYRAMID']]
# PREDICTED CLUSTER:  [['HORN' 'FLAG' 'SPHERE' 'FIDDLE']
#  ['FIGHT' 'CONE' 'RECORDER' 'DOMAIN']
#  ['AREA' 'PROCESSOR' 'BARRIER' 'CHAIN']
#  ['FIGHT' 'TRIANGLE' 'FLARE' 'FIELD']]
#
# ACTUAL CLUSTER: [['DUMP' 'MESS' 'PIGPEN' 'STY']
#  ['FIRM' 'SOLID' 'SOUND' 'STABLE']
#  ['CARAMEL' 'PEANUTS' 'POPCORN' 'PRIZE']
#  ['CHARLEY' 'CRAZY' 'DARK' 'GIFT']]
# PREDICTED CLUSTER:  [['SOLID' 'DUMP' 'CHARLEY' 'CRAZY']
#  ['GIFT' 'PIGPEN' 'STY' 'PRIZE']
#  ['STABLE' 'FIRM' 'SOUND' 'MESS']
#  ['POPCORN' 'STABLE' 'PEANUTS' 'CARAMEL']]
#
# ACTUAL CLUSTER: [['CARD' 'CHARACTER' 'JOKER' 'LAUGH']
#  ['BAND' 'BENCH' 'DUMBBELL' 'MAT']
#  ['AIRHEAD' 'MAR' 'MOUND' 'SNICKER']
#  ['BUMP' 'CHESS' 'DEMON' 'DIAL']]
# PREDICTED CLUSTER:  [['DUMBBELL' 'BENCH' 'CHESS' 'MAT']
#  ['DEMON' 'BAND' 'CARD' 'CHARACTER']
#  ['JOKER' 'LAUGH' 'MAR' 'SNICKER']
#  ['DIAL' 'MOUND' 'BUMP' 'AIRHEAD']]
#
# ACTUAL CLUSTER: [['BRUSH' 'CANVAS' 'EASEL' 'PALETTE']
#  ['DRIVE' 'NEUTRAL' 'PARK' 'REVERSE']
#  ['COMB' 'GEAR' 'SAW' 'ZIPPER']
#  ['FIRST' 'FOLDING' 'HIGH' 'LAWN']]
# PREDICTED CLUSTER:  [['NEUTRAL' 'PARK' 'PALETTE' 'LAWN']
#  ['CANVAS' 'DRIVE' 'EASEL' 'FOLDING']
#  ['HIGH' 'GEAR' 'COMB' 'ZIPPER']
#  ['FIRST' 'BRUSH' 'SAW' 'FOLDING']]
#
# ACTUAL CLUSTER: [['BUNKER' 'FAIRWAY' 'GREEN' 'ROUGH']
#  ['ENOUGH' 'MERCY' 'STOP' 'UNCLE']
#  ['BAWDY' 'BLUE' 'COARSE' 'RISQUE']
#  ['BOUGH' 'COUGH' 'DOUGH' 'TOUGH']]
# PREDICTED CLUSTER:  [['STOP' 'TOUGH' 'ROUGH' 'MERCY']
#  ['BLUE' 'BOUGH' 'BAWDY' 'GREEN']
#  ['COUGH' 'COARSE' 'UNCLE' 'FAIRWAY']
#  ['DOUGH' 'DOUGH' 'RISQUE' 'ENOUGH']]
#
# ACTUAL CLUSTER: [['CANADIEN' 'CELTIC' 'PACKER' 'YANKEE']
#  ['CRIMP' 'CURL' 'FEATHER' 'TEASE']
#  ['GLITTER' 'GLUE' 'MACARONI' 'PAPER']
#  ['DOODLE' 'GOOSE' 'PARACHUTE' 'ROD']]
# PREDICTED CLUSTER:  [['GOOSE' 'CURL' 'FEATHER' 'MACARONI']
#  ['TEASE' 'GLITTER' 'PARACHUTE' 'PACKER']
#  ['DOODLE' 'Celtic' 'ROD' 'YANKEE']
#  ['GLUE' 'CRIMP' 'CANADIEN' 'CELTIC']]
#
# ACTUAL CLUSTER: [['BARB' 'BRISTLE' 'NEEDLE' 'SPINE']
#  ['BRIDGE' 'NECK' 'PEG' 'STRING']
#  ['CHARGE' 'MOVE' 'SERVE' 'SUE']
#  ['MAY' 'MIGHT' 'TONIGHT' 'WISH']]
# PREDICTED CLUSTER:  [['BARB' 'BRIDGE' 'SERVE' 'SPINE']
#  ['MAY' 'TONIGHT' 'NECK' 'WISH']
#  ['PEG' 'MIGHT' 'NEEDLE' 'CHARGE']
#  ['MOVE' 'BRISTLE' 'SERVE' 'STRONG']]
#
# ACTUAL CLUSTER: [['CHARM' 'CURSE' 'HEX' 'SPELL']
#  ['FLUE' 'GRATE' 'LOG' 'POKER']
#  ['CARDS' 'CHIPS' 'DICE' 'SLOTS']
#  ['CRUMBLE' 'MELT' 'SHRED' 'SLICE']]
# PREDICTED CLUSTER:  [['CHIPS' 'POKER' 'SLOTS' 'HEX']
#  ['GRATE' 'SHRED' 'LOG' 'CURSE']
#  ['CRUMBLE' 'MELT' 'SLICE' 'CHARM']
#  ['CARDS' 'SPELL' 'FLUE' 'DICE']]
#
# ACTUAL CLUSTER: [['HEAVE' 'LURCH' 'PITCH' 'REEL']
#  ['IDEA' 'PERSON' 'PLACE' 'THING']
#  ['AMBIENT' 'HOUSE' 'JUNGLE' 'TRANCE']
#  ['BLOND' 'TRAY' 'TREE' 'WEDNESDAY']]
# PREDICTED CLUSTER:  [['BLOND' 'TREE' 'PLACE' 'TRAY']
#  ['THING' 'IDEA' 'PITCH' 'REEL']
#  ['JUNGLE' 'TRANCE' 'WEDNESDAY' 'HEAVE']
#  ['AMBIENT' 'HOUSE' 'LURCH' 'REEL']]
#
# ACTUAL CLUSTER: [['AUNT' 'COUSIN' 'MOTHER' 'NEPHEW']
#  ['DAFFY' 'KOOKY' 'QUIRKY' 'WACKY']
#  ['DAISY' 'DEWEY' 'DONALD' 'SCROOGE']
#  ['ALARM' 'BIOLOGICAL' 'CUCKOO' 'GRANDFATHER']]
# PREDICTED CLUSTER:  [['NEPHEW' 'DAFFY' 'MOTHER' 'AUNT']
#  ['SCROOGE' 'COUSIN' 'DEWEY' 'AUNT']
#  ['QUIRKY' 'WACKY' 'CUCKOO' 'DAISY']
#  ['KOOKY' 'GRANDFATHER' 'ALARM' 'BIOLOGICAL']]
#
# ACTUAL CLUSTER: [['BLUE' 'DOWN' 'HANGDOG' 'SORRY']
#  ['DUCK' 'GROUSE' 'HAWK' 'SWALLOW']
#  ['GRIFFIN' 'MUNSTER' 'PARTRIDGE' 'PICKLES']
#  ['MART' 'POP' 'STREET' 'SWISS']]
# PREDICTED CLUSTER:  [['HAWK' 'DUCK' 'PICKLES' 'SWALLOW']
#  ['BLUE' 'STREET' 'SORRY' 'SWISS']
#  ['DOWN' 'GROUSE' 'MART' 'MUNSTER']
#  ['GRIFFIN' 'PARTRIDGE' 'MUNSTER' 'PICKLES']]
#
# ACTUAL CLUSTER: [['ORCA' 'PANDA' 'SKUNK' 'ZEBRA']
#  ['CHAIN' 'SERIES' 'STRING' 'TRAIN']
#  ['BASS' 'DOVE' 'DESERT' 'WIND']
#  ['BEAR' 'SAND' 'SPEED' 'TOURIST']]
# PREDICTED CLUSTER:  [['BEAR' 'BASS' 'SKUNK' 'ZEBRA']
#  ['DOVE' 'ORCA' 'PANDA' 'DESERT']
#  ['CHAIN' 'SAND' 'SERIES' 'TRAIN']
#  ['WIND' 'SPEED' 'SQUASH' 'SQUASH']]
#
# ACTUAL CLUSTER: [['CON' 'DUPE' 'FOOL' 'TRICK']
#  ['DOPE' 'SCOOP' 'SKINNY' 'WORD']
#  ['CANT' 'LEAN' 'LIST' 'SLOPE']
#  ['BOOB' 'EGGSHELL' 'GIGGLE' 'HELLO']]
# PREDICTED CLUSTER:  [['DOPE' 'CANT' 'GIGGLE' 'SLOPE']
#  ['EGGSHELL' 'BOOB' 'SKINNY' 'HELLO']
#  ['CON' 'WORD' 'TRICK' 'DUPE']
#  ['LEAN' 'FOOL' 'SCOOP' 'LIST']]
#
# ACTUAL CLUSTER: [['CHARLATAN' 'FRAUD' 'QUACK' 'SHAM']
#  ['NOISE' 'PEEP' 'SOUND' 'WORD']
#  ['HAM' 'HOT DOG' 'PEACOCK' 'SHOWBOAT']
#  ['BUG' 'PORK' 'SPEED' 'TWEET']]
# PREDICTED CLUSTER:  [['PORK' 'SHAM' 'SPEED' 'TWEET']
#  ['QUACK' 'HAM' 'CHARLATAN' 'BUG']
#  ['FRAUD' 'NOISE' 'SOUND' 'WORD']
#  ['PEEP' 'SHOWBOAT' 'PEACOCK' 'HOT DOG']]
#
# ACTUAL CLUSTER: [['BARGE' 'CRAFT' 'SHIP' 'VESSEL']
#  ['BEST' 'CHAMP' 'GOAT' 'LEGEND']
#  ['ABOUT' 'CONCERNING' 'ON' 'TOWARD']
#  ['HARE' 'I' 'MUSSEL' 'NAVAL']]
# PREDICTED CLUSTER:  [['BARGE' 'CONCERNING' 'GOAT' 'SHIP']
#  ['ABOUT' 'BEST' 'CHAMP' 'MUSSEL']
#  ['HARE' 'LEGEND' 'NAVAL' 'TOWARD']
#  ['ON' 'VESSEL' 'I' 'CRAFT']]
#
# ACTUAL CLUSTER: [['GUSTO' 'PASSION' 'RELISH' 'ZEST']
#  ['BEAUCOUP' 'MOLTO' 'MUCHO' 'MULTI']
#  ['BRICK' 'FISH TANK' 'MICROWAVE' 'SHOEBOX']
#  ['JENNY' 'LIME' 'MORTAR' 'PICKLE']]
# PREDICTED CLUSTER:  [['' '' '' '']
#  ['' '' '' '']
#  ['' '' '' '']
#  ['' '' '' '']]
#
# ACTUAL CLUSTER: [['CREAM' 'EGGSHELL' 'IVORY' 'VANILLA']
#  ['CRUCIFIX' 'GARLIC' 'MIRROR' 'STAKE']
#  ['BEEF' 'PORK' 'POULTRY' 'VENISON']
#  ['ROW' 'QUARREL' 'SPAT' 'TIFF']]
# PREDICTED CLUSTER:  [['PORK' 'EGGSHELL' 'IVORY' 'STAKE']
#  ['QUARREL' 'VENISON' 'SPAT' 'GARLIC']
#  ['ROW' 'MIRROR' 'TIFF' 'VANILLA']
#  ['CRUCIFIX' 'BEEF' 'STAKE' 'PULLED']]
#
# ACTUAL CLUSTER: [['GOBLET' 'SNIFTER' 'TUMBLER' 'STEIN']
#  ['CLARINET' 'FLUTE' 'OBOE' 'SAXOPHONE']
#  ['BISHOP' 'FROST' 'OLDS' 'POUND']
#  ['BALLOON' 'BASSOON' 'COFFEE' 'FRICASSEE']]
# PREDICTED CLUSTER:  [['FROST' 'SNIFTER' 'OLDS' 'COFFEE']
#  ['BASSOON' 'FLUTE' 'SAXOPHONE' 'TUMBLER']
#  ['STEIN' 'CLARINET' 'OBOE' 'BISHOP']
#  ['FRICASSEE' 'BALLOON' 'GOBLET' 'POUND']]
#
# ACTUAL CLUSTER: [['BREAD' 'BACON' 'LETTUCE' 'TOMATO']
#  ['BLOCK' 'CLOG' 'JAM' 'STOP']
#  ['DOUBLE' 'HIT' 'RUN' 'WALK']
#  ['FRY' 'TALK' 'WONDER' 'WORLD']]
# PREDICTED CLUSTER:  [['WONDER' 'BREAD' 'TALK' 'CLOG']
#  ['BLOCK' 'TOMATO' 'WORLD' 'STOP']
#  ['BACON' 'DOUBLE' 'RUN' 'WALK']
#  ['LETTUCE' 'HIT' 'FRY' 'JAM']]
#
# ACTUAL CLUSTER: [['DIRECT' 'HEAD' 'LEAD' 'RUN']
#  ['BALLOON' 'ERASER' 'GALOSH' 'TIRE']
#  ['BLUE' 'EARRING' 'LAMP' 'WISHES']
#  ['BULL' 'CROSS' 'HERRING' 'VELVET']]
# PREDICTED CLUSTER:  [['ERASER' 'HEAD' 'LEAD' 'TIRE']
#  ['BALLOON' 'BLUE' 'CROSS' 'HERRING']
#  ['WISHES' 'GALOSH' 'RUN' 'ERASER']
#  ['LAMP' 'BULL' 'HEAD' 'VELVET']]
#
# ACTUAL CLUSTER: [['FLOAT' 'FLY' 'GLIDE' 'SOAR']
#  ['BUG' 'MIKE' 'TAP' 'WIRE']
#  ['CHECK' 'MARK' 'TICK' 'X']
#  ['40' 'COLE' 'PAIN' 'TIP']]
# PREDICTED CLUSTER:  [['COLE' 'FLY' 'MARK' 'MIKE']
#  ['BUG' 'CHECK' 'TICK' 'WIRE']
#  ['SOAR' 'PAIN' 'TAP' 'TIP']
#  ['GLIDE' 'FLOAT' 'TICK' 'TIPTOE']]
#
# ACTUAL CLUSTER: [['BACKUP' 'COPY' 'EXTRA' 'SPARE']
#  ['ALLEY' 'BALL' 'LANE' 'PIN']
#  ['MUG' 'PEN' 'TEE' 'TOTE']
#  ['ATE' 'FOR' 'TOO' 'WON']]
# PREDICTED CLUSTER:  [['TOO' 'LANE' 'BACKUP' 'PEN']
#  ['TEE' 'ATE' 'PIN' 'COPY']
#  ['EXTRA' 'SPARE' 'MUG' 'BALL']
#  ['FOR' 'ALLEY' 'TOTE' 'WON']]
#
# ACTUAL CLUSTER: [['FERRY' 'JUNK' 'TUG' 'YACHT']
#  ['CLUB' 'CUBAN' 'MELT' 'SUB']
#  ['FLANK' 'LOIN' 'ROUND' 'SHANK']
#  ['CHUCK' 'JOSH' 'ROB' 'SUE']]
# PREDICTED CLUSTER:  [['JOSH' 'CUBAN' 'LOIN' 'MELT']
#  ['CHUCK' 'ROUND' 'SHANK' 'YACHT']
#  ['SUB' 'FERRY' 'JUNK' 'JUNK']
#  ['CLUB' 'ROB' 'SUE' 'FLANK']]
#
# ACTUAL CLUSTER: [['EXAMPLE' 'IDEAL' 'MODEL' 'SYMBOL']
#  ['CAR' 'CONDUCTOR' 'STATION' 'TRACK']
#  ['CYMBAL' 'SCIMITAR' 'SIMMER' 'SYMPHONY']
#  ['DRUM' 'MARK' 'WAX' 'WIG']]
# PREDICTED CLUSTER:  [['DRUM' 'WAX' 'CYMBAL' 'SYMBOL']
#  ['CONDUCTOR' 'SCIMITAR' 'MARK' 'SYMPHONY']
#  ['STATION' 'MODEL' 'IDEAL' 'TRACK']
#  ['EXAMPLE' 'SIMMER' 'CAR' 'WIG']]
#
# ACTUAL CLUSTER: [['COW' 'DOE' 'HEN' 'MARE']
#  ['I' 'IT' 'THEY' 'WE']
#  ['D' 'L' 'M' 'V']
#  ['EWE' 'U' 'YEW' 'YOU']]
# PREDICTED CLUSTER:  [['VMARE' 'MARE' 'DOE' 'COW']
#  ['HEN' 'YOU' 'L' 'D']
#  ['I' 'THEY' 'EWE' 'IT']
#  ['V' 'WE' 'U' 'YEW']]
#
# ACTUAL CLUSTER: [['MINT' 'NEW' 'ORIGINAL' 'UNUSED']
#  ['ATTENDING' 'FELLOW' 'INTERN' 'RESIDENT']
#  ['COUNTRYMAN' 'EAR' 'FRIEND' 'ROMAN']
#  ['PERFECT' 'POCKET' 'TIMES' 'TOWN']]
# PREDICTED CLUSTER:  [['ATTENDING' 'COUNTRYMAN' 'EAR' 'MINT']
#  ['FELLOW' 'FRIEND' 'NEW' 'ORIGINAL']
#  ['PERFECT' 'POCKET' 'ROMAN' 'TIMES']
#  ['RESIDENT' 'TIMES' 'TOWN' 'USED']]
#
# ACTUAL CLUSTER: [['FAINT' 'LIGHT' 'MILD' 'SOFT']
#  ['GRAND' 'GREAT' 'LOFTY' 'NOBLE']
#  ['BOTTLE' 'GIRAFFE' 'GUITAR' 'LAMP']
#  ['CAB' 'COUNT' 'DIZZY' 'DUKE']]
# PREDICTED CLUSTER:  [['GIRAFFE' 'COUNT' 'Duke' 'FAINT']
#  ['LIGHT' 'GRAND' 'BOTTLE' 'DIZZY']
#  ['CAB' 'LAMP' 'GUITAR' 'LOFTY']
#  ['MILD' 'SOFT' 'GREAT' 'NOBLE']]
#
# ACTUAL CLUSTER: [['FALL' 'SLIP' 'SPILL' 'TRIP']
#  ['MINERAL' 'SPRING' 'STILL' 'TAP']
#  ['CORSET' 'DIABOLO' 'HOURGLASS' 'WASP']
#  ['BOO-BOO' 'BROWN' 'HONEY' 'TEDDY']]
# PREDICTED CLUSTER:  [['BOO-BOO' 'DIABOLO' 'FALL' 'HONEY']
#  ['BROWN' 'CORSET' 'HOURGLASS' 'SPILL']
#  ['STILL' 'TEDDY' 'TAP' 'WASP']
#  ['MINERAL' 'SPRING' 'SLIP' 'TRIP']]
#
# ACTUAL CLUSTER: [['COUPLE' 'JOIN' 'LINK' 'TIE']
#  ['BOTHER' 'HANDFUL' 'PAIN' 'PEST']
#  ['FEW' 'MANY' 'SEVERAL' 'SOME']
#  ['FOOL' 'LOVERS' 'MAGICIAN' 'TOWER']]
# PREDICTED CLUSTER:  [['COUPLE' 'JOIN' 'FEW' 'MAGICIAN']
#  ['SEVERAL' 'PEST' 'TOWER' 'HANDFUL']
#  ['LOVERS' 'MANY' 'TIE' 'BOTHER']
#  ['SOME' 'FOOL' 'PAIN' 'LINK']]
#
# ACTUAL CLUSTER: [['CLUSTER' 'COLLECTION' 'CONSTELLATION' 'GROUP']
#  ['BALLET' 'DEBUT' 'RAPPORT' 'TAROT']
#  ['MONSTER' 'PSYCHO' 'SEVEN' 'ZODIAC']
#  ['DRACONIAN' 'HYDRANT' 'LEONARDO' 'LIBRARY']]
# PREDICTED CLUSTER:  [['DRACONIAN' 'LEONARDO' 'PSYCHO' 'ZODIAC']
#  ['BALLET' 'COLLECTION' 'GROUP' 'HYDRANT']
#  ['CONSTELLATION' 'DEBUT' 'DRAGON' 'MONSTER']
#  ['SEVEN' 'PSYCHO' 'RAPPORT' 'SEVEN']]
#
# ACTUAL CLUSTER: [['EGG' 'GOAD' 'SPUR' 'URGE']
#  ['JAWBREAKER' 'MEATBALL' 'MOZZARELLA' 'ORANGE']
#  ['DAIRY' 'FROZEN' 'PRODUCE' 'SNACK']
#  ['BANANAS' 'FIGURE' 'FISH' 'STEADY']]
# PREDICTED CLUSTER:  [['URGE' 'FISH' 'MEATBALL' 'EGG']
#  ['FROZEN' 'JAWBREAKER' 'PRODUCE' 'GOAD']
#  ['MOZZARELLA' 'DAIRY' 'SPUR' 'STEADY']
#  ['BANANAS' 'ORANGE' 'FISH' 'DAIRY']]
#
# ACTUAL CLUSTER: [['MISTLETOE' 'REINDEER' 'SNOWMAN' 'STOCKING']
#  ['DISPLAY' 'EXHIBIT' 'PRESENT' 'SHOW']
#  ['BAGEL' 'CHEERIO' 'DONUT' 'LIFESAVER']
#  ['CANDY CANE' 'CROSSWALK' 'REFEREE' 'TIGER']]
# PREDICTED CLUSTER:  [['' '' '' '']
#  ['' '' '' '']
#  ['' '' '' '']
#  ['' '' '' '']]
#
# ACTUAL CLUSTER: [['BALL' 'BASE' 'BAT' 'GLOVE']
#  ['BLOW' 'LICK' 'SOCK' 'STRIKE']
#  ['BOOT' 'IRON' 'THIMBLE' 'TOP HAT']
#  ['BAD' 'BUGS' 'DUST' 'HONEY']]
# PREDICTED CLUSTER:  [['IRON' 'BAT' 'SOCK' 'STRIKE']
#  ['BUGS' 'THIMBLE' 'HONEY' 'BOOT']
#  ['BLOW' 'DUST' 'BALL' 'GLOVE']
#  ['LICK' 'TOP HAT' 'BAD' 'IRON']]
#
# ACTUAL CLUSTER: [['BODY' 'CANON' 'OEUVRE' 'WORKS']
#  ['FUJI' 'HOOD' 'OLYMPUS' 'WHITNEY']
#  ['INSERT' 'JACKET' 'RECORD' 'SLEEVE']
#  ['HANDS' 'MARACA' 'POLAROID' 'SNOWGLOBE']]
# PREDICTED CLUSTER:  [['BODY' 'Fuji' 'OEVRE' 'POLAROID']
#  ['MARACA' 'CANON' 'HOOD' 'RECORD']
#  ['OEUVRE' 'SNOWGLOBE' 'JACKET' 'WORKS']
#  ['HANDS' 'FUJI' 'INSERT' 'POLAROID']]
#
# ACTUAL CLUSTER: [['DODGE' 'DUCK' 'ESCAPE' 'SKIRT']
#  ['BIRDS' 'NOTORIOUS' 'REBECCA' 'ROPE']
#  ['GOOSE' 'HOBBES' 'ROBIN' 'WATSON']
#  ['COTTAGE' 'CREAM' 'SAY' 'STRING']]
# PREDICTED CLUSTER:  [['DUCK' 'CREAM' 'SKIRT' 'WATSON']
#  ['ESCAPE' 'NOTORIOUS' 'REBECCA' 'SAY']
#  ['BIRDS' 'DUCK' 'GOOSE' 'HOBBES']
#  ['ROPE' 'ROBIN' 'ROCK' 'SKOTTI']]
#
# ACTUAL CLUSTER: [['FERRIS WHEEL' 'MERRY-GO-ROUND' 'ROLLER COASTER' 'TILT-A-WHIRL']
#  ['CLEARANCE' 'GO-AHEAD' 'GREEN LIGHT' 'THUMBS-UP']
#  ['CINDERELLA' 'DAVID-AND-GOLIATH' 'RAGS-TO-RICHES' 'UNDERDOG']
#  ['BUMPER-TO-BUMPER' 'BUTTERMILK' 'RUMPELSTILTSKIN' 'TAILGATE']]
# PREDICTED CLUSTER:  [['GO-AHEAD' 'GREEN LIGHT' 'TAILGATE' 'MERRY-GO-ROUND']
#  ['CINDERELLA' 'BUMPER-TO-BUMPER' 'RAGS-TO-RICHES' 'FERRIS WHEEL']
#  ['DAVID-AND-GOLIATH' 'RUMPELSTILTSKIN' 'BUMPER-TO-BUMPER' 'TILT-A-WHIRL']
#  ['THUMBS-UP' 'CINDERELLA' 'RUMPELSTILTSKIN' 'FERRIS WHEEL']]
#
# ACTUAL CLUSTER: [['ELEGANCE' 'GRACE' 'STYLE' 'TASTE']
#  ['BAKE' 'BASK' 'SUN' 'TAN']
#  ['AFFECT' 'IMPACT' 'MOVE' 'TOUCH']
#  ['SEN' 'SIGHT' 'SINE' 'SOUR']]
# PREDICTED CLUSTER:  [['' '' '' '']
#  ['' '' '' '']
#  ['' '' '' '']
#  ['' '' '' '']]
#
# ACTUAL CLUSTER: [['CUP' 'LID' 'STIRRER' 'STRAW']
#  ['BAT' 'MOTH' 'OWL' 'WOLF']
#  ['BEET' 'BRICK' 'CARDINAL' 'POPPY']
#  ['ACTION' 'BALLPARK' 'GO' 'STICK']]
# PREDICTED CLUSTER:  [['STICK' 'BALLPARK' 'OWL' 'STRAW']
#  ['BAT' 'CARDINAL' 'MOOTH' 'BEET']
#  ['ACTION' 'CUP' 'LID' 'POPPY']
#  ['BRICK' 'WOLF' 'STIRRER' 'MOTH']]
#
# 65
# Success Rate: 0.015384615384615385
# Purity: 0.45096153846153847
# Count of Missed samples: 5
